# %% [markdown]
# # Librerías

# %%
import pandas as pd

# %% [markdown]
# # Constantes

# %%
fichero_historico = './data/historical_air_temp.csv'

# %% [markdown]
# # Carga de datos

# %%
data = pd.read_csv(fichero_historico, sep=";")

data = data[["fecha", "ambiente"]]

data

# %%
data.info()

# %%
data.to_csv('data/datos_historico.csv', index=False)
